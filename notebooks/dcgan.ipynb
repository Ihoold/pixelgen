# %%
from unittest import mock
import os
import numpy as np
import tensorflow as tf
import json
from tensorflow.python.estimator import estimator
from tensorflow.python.training.basic_session_run_hooks import CheckpointSaverHook, meta_graph
from tensorflow.python.platform import tf_logging as logging

# %%
RUN_NAME = 'DCGAN_2_in_ks3'

# %% [markdown]
# Setting things up.

# %%
from google.colab import drive, auth

drive.mount('/content/gdrive')
# set paths
ROOT = %pwd
MODEL_DIR = 'gs://tputestingmnist/{}/'.format(RUN_NAME)
LOG_DIR = MODEL_DIR
GOOGLE_DRIVE_DIR = '/content/gdrive/My Drive/Programowanie/PixelGen/{}'.format(RUN_NAME)
TF_MASTER = 'grpc://{}'.format(os.environ['COLAB_TPU_ADDR'])

auth.authenticate_user()
  
# Upload credentials to TPU.
with tf.Session(TF_MASTER) as sess:    
    with open('/content/adc.json', 'r') as f:
        auth_info = json.load(f)
    tf.contrib.cloud.configure_gcs(sess, credentials=auth_info)

PREFIX = RUN_NAME
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).
#
# WARNING: The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
# If you depend on functionality not listed there, please file an issue.

# %%
data_file = 'gs://tputestingmnist/datasets/characters_front.tfrecords'

CHANNELS = 4
LATENT_DIM = 128
ADD_NOISE_TO_EXAMPLE = True


def parser(serialized_example):
    """Parses a single example into image and label tensors."""
    features = tf.parse_single_example(
        serialized_example,
        features={
            'image_raw': tf.FixedLenFeature([], tf.string),
            'label': tf.FixedLenFeature([], tf.int64)   # label is unused
        })

    image = tf.decode_raw(features['image_raw'], tf.uint8)
    image.set_shape([48 * 48 * 4])
    image = tf.reshape(image, [48, 48, 4])[:,:,:CHANNELS]
    # Normalize the values of the image from [0, 255] to [-1.0, 1.0]
    image = tf.cast(image, dtype=tf.float32) / 127.5 - 1

    return image


def make_input_fn(is_training=True):
    def input_fn(params):
        batch_size = params['batch_size']
        dataset = tf.data.TFRecordDataset(data_file).map(parser).cache().shuffle(batch_size)
        if is_training:
            dataset = dataset.repeat()
        images = dataset.prefetch(batch_size).batch(batch_size, drop_remainder=True).make_one_shot_iterator().get_next()

        if ADD_NOISE_TO_EXAMPLE:
            images += tf.random_normal(shape=tf.shape(images), mean=0.0, stddev=0.1, dtype=tf.float32)

        features = {
            'real_images': images,
            'random_noise': tf.random_uniform([params['batch_size'], LATENT_DIM], -1, 1, dtype=tf.float32)
        }
        return features, None
    return input_fn


def noise_input_fn(params):  
    noise_dataset = tf.data.Dataset.from_tensors(tf.constant(np.random.uniform(-1, 1, (params['batch_size'], LATENT_DIM)), dtype=tf.float32))
    return {'random_noise': noise_dataset.make_one_shot_iterator().get_next()}, None

# %% [markdown]
# Feeding data to the network

# %% [markdown]
# Creating sample images

# %%
import matplotlib.pyplot as plt

R, C = 4, 4
EXAMPLES = R * C


def images_to_zero_one(images):
    return np.clip(np.array(images) * 0.5 + 0.5, 0., 1.)


def save_imgs(epoch, images):
    if not os.path.exists(GOOGLE_DRIVE_DIR):
        os.mkdir(GOOGLE_DRIVE_DIR)
    
    # Rescale images to 0 - 1
    images = images_to_zero_one(images)
    fig, axs = plt.subplots(R, C)

    for i in range(R):
        for j in range(C):
            axs[i,j].imshow(images[C*i + j])
            axs[i,j].axis('off')
          
    fig.savefig(os.path.join(GOOGLE_DRIVE_DIR, '{}.png'.format(epoch)))
    plt.close()

# %% [markdown]
# Architecture

# %%
KERNEL_SIZE = 3
DROPOUT_PROB = 0.5
ALPHA = 0.2


def _leaky_relu(x):
    return tf.nn.leaky_relu(x, alpha=ALPHA)


def _relu(x):
    return tf.nn.relu(x)


def _batch_norm(x, is_training, name):
    return tf.layers.batch_normalization(x, momentum=0.8, epsilon=1e-5, 
                                         training=is_training, name=name)


def _dense(x, neurons, name, activation=None):
    return tf.layers.dense(x, neurons, name=name, activation=activation,
                           kernel_initializer=tf.truncated_normal_initializer(stddev=0.02))


def _conv2d(x, filters, stride, name, activation=None):
    return tf.layers.conv2d(x, filters, [KERNEL_SIZE, KERNEL_SIZE], 
                            strides=[stride, stride], activation=activation,
                            padding='same', name=name,
                            kernel_initializer=tf.truncated_normal_initializer(stddev=0.02))


def _deconv2d(x, filters, stride, name, activation=None):
    return tf.layers.conv2d_transpose(x, filters, [KERNEL_SIZE, KERNEL_SIZE],
                                      strides=[stride, stride], activation=activation,
                                      padding='same', name=name,
                                      kernel_initializer=tf.truncated_normal_initializer(stddev=0.02))


def _dropout(x, name):
    return tf.nn.dropout(x, rate=DROPOUT_PROB, name=name)



def convolution_block(x, filters, resize_factor, is_training, index,
                      activation=_leaky_relu, dropout=False, batch_norm=True):

    x = _conv2d(x, filters=filters, stride=resize_factor, activation=activation, name='conv_{}'.format(index))

    if batch_norm:
        x = _batch_norm(x, is_training, name='bn_conv_{}'.format(index))

    if dropout:
        x = _dropout(x, name='drop_deconv_{}'.format(index))

#     x = activation(x)
    return x


def deconvolution_block(x, filters, resize_factor, is_training, index,
                        activation=_relu, dropout=False, batch_norm=True):

    x = _deconv2d(x, filters=filters, stride=resize_factor, activation=activation, name='deconv_{}'.format(index))

    if batch_norm:
        x = _batch_norm(x, is_training, name='bn_deconv_{}'.format(index))

    if dropout:
        x = _dropout(x, name='drop_deconv_{}'.format(index))

#     x = activation(x)
    return x


class Dcgan:
    
    @staticmethod
    def discriminator(x, is_training=True, scope='Discriminator'):
        with tf.variable_scope(scope, reuse=tf.AUTO_REUSE):
            x = convolution_block(x, 64, 2, is_training, 11, batch_norm=False)
            x = convolution_block(x, 128, 2, is_training, 12)
            x = convolution_block(x, 256, 2, is_training, 13)
            x = convolution_block(x, 512, 2, is_training, 14)

            x = tf.layers.Flatten()(x)
            x = _dense(x, neurons=1, name='d_dense')

            return x

    @staticmethod
    def generator(x, is_training=True, scope='Generator'):
        with tf.variable_scope(scope, reuse=tf.AUTO_REUSE):
            x = _dense(x, 1024 * 3 * 3, activation=tf.nn.relu, name='g_dense')
            x = tf.reshape(x, [-1, 3, 3, 1024])
           
            x = deconvolution_block(x, 512, 2, is_training, 21)
            x = deconvolution_block(x, 256, 2, is_training, 22)
            x = deconvolution_block(x, 128, 2, is_training, 23)
            x = deconvolution_block(x, CHANNELS, 2, is_training, 24, activation=tf.tanh, batch_norm=False)

            return x
        
model = Dcgan()

# %% [markdown]
# Model function

# %%
def model_fn(features, labels, mode, params):
    # PREDICT #
    if mode == tf.estimator.ModeKeys.PREDICT:
        random_noise = features['random_noise']
        generated_images = model.generator(random_noise, is_training=False)
        predictions = {'generated_images': generated_images}
        return tf.contrib.tpu.TPUEstimatorSpec(mode=mode, predictions=predictions)
    
    real_images = features['real_images']
    random_noise = features['random_noise']
    generated_images = model.generator(random_noise, is_training=(mode == tf.estimator.ModeKeys.TRAIN))

    # Discriminator loss
    d_on_data_logits = tf.squeeze(model.discriminator(real_images))
    d_on_data_labels = tf.ones_like(d_on_data_logits)

    d_on_g_logits = tf.squeeze(model.discriminator(generated_images))
    d_on_g_labels = tf.zeros_like(d_on_g_logits)

    d_loss = tf.contrib.gan.losses.wargs.modified_discriminator_loss(
        discriminator_real_outputs=d_on_data_logits,
        discriminator_gen_outputs=d_on_g_logits,
        reduction=tf.losses.Reduction.NONE,
        label_smoothing=0.2
    )

    # Generator loss
    g_loss = tf.contrib.gan.losses.wargs.modified_generator_loss(
        discriminator_gen_outputs=d_on_g_logits,
        reduction=tf.losses.Reduction.NONE
    )

    # TRAIN #
    if mode == tf.estimator.ModeKeys.TRAIN:
        d_loss = tf.reduce_mean(d_loss)
        g_loss = tf.reduce_mean(g_loss)
        d_optimizer = tf.train.AdamOptimizer(learning_rate=0.0002, beta1=0.5)
        g_optimizer = tf.train.AdamOptimizer(learning_rate=0.0002, beta1=0.5)

        d_optimizer = tf.contrib.tpu.CrossShardOptimizer(d_optimizer)
        g_optimizer = tf.contrib.tpu.CrossShardOptimizer(g_optimizer)

        with tf.control_dependencies(tf.get_collection(tf.GraphKeys.UPDATE_OPS)):
            d_step = d_optimizer.minimize(d_loss, var_list=tf.get_collection(tf.GraphKeys.GLOBAL_VARIABLES,
                                                                             scope='Discriminator'))
            g_step = g_optimizer.minimize(g_loss, var_list=tf.get_collection(tf.GraphKeys.GLOBAL_VARIABLES,
                                                                             scope='Generator'))

            increment_step = tf.assign_add(tf.train.get_or_create_global_step(), 1)
            joint_op = tf.group([d_step, g_step, increment_step])

            return tf.contrib.tpu.TPUEstimatorSpec(mode=mode, loss=g_loss, train_op=joint_op)

    # EVAL #
    elif mode == tf.estimator.ModeKeys.EVAL:
        def _eval_metric_fn(d_loss, g_loss, d_real_labels, d_gen_lanels, d_real_logits, d_gen_logits):
            return {
                'discriminator_loss': tf.metrics.mean(d_loss),
                'generator_loss': tf.metrics.mean(g_loss),
                'discriminator_real_accuracy': tf.metrics.accuracy(labels=d_real_labels, predictions=tf.math.round(tf.sigmoid(d_real_logits))),
                'discriminator_gen_accuracy': tf.metrics.accuracy(labels=d_gen_lanels, predictions=tf.math.round(tf.sigmoid(d_gen_logits))),
            }

        return tf.contrib.tpu.TPUEstimatorSpec(mode=mode, loss=tf.reduce_mean(g_loss),
                                               eval_metrics=(_eval_metric_fn, [d_loss, g_loss, d_on_data_labels,
                                                                               d_on_g_labels, d_on_data_logits, d_on_g_logits]))

# %% [markdown]
# Training!

# %%
BATCH_SIZE = 1024
EPOCHS = 10000
EVAL_EPOCHS = 1000


config = tf.contrib.tpu.RunConfig(
    master=TF_MASTER,
    save_checkpoints_steps=EVAL_EPOCHS,
    save_checkpoints_secs=None,
    save_summary_steps=EVAL_EPOCHS,
    model_dir=MODEL_DIR,
    keep_checkpoint_max=3,
    tpu_config=tf.contrib.tpu.TPUConfig(iterations_per_loop=EVAL_EPOCHS))

# TPU-based estimator used for TRAIN and EVAL
est = tf.contrib.tpu.TPUEstimator(
    model_fn=model_fn,
    use_tpu=True,
    config=config,
    train_batch_size=BATCH_SIZE,
    eval_batch_size=BATCH_SIZE)

# CPU-based estimator used for PREDICT (generating images)
cpu_est = tf.contrib.tpu.TPUEstimator(
    model_fn=model_fn,
    use_tpu=False,
    config=config,
    predict_batch_size=EXAMPLES)

current_step = estimator._load_global_step_from_checkpoint_dir(MODEL_DIR)
tf.logging.info('Starting training')

while current_step < EPOCHS:
    next_checkpoint = int(min(current_step + EVAL_EPOCHS, EPOCHS))
    est.train(input_fn=make_input_fn(), max_steps=next_checkpoint)
    current_step = next_checkpoint
    tf.logging.info('Finished training step %d' % current_step)

    # Evaluation
    metrics = est.evaluate(input_fn=make_input_fn(False), steps=1)
    tf.logging.info('Finished evaluating')
    tf.logging.info(metrics)

    # Render some generated images
    generated_iter = cpu_est.predict(input_fn=noise_input_fn)
    images = [p['generated_images'] for p in generated_iter]
    save_imgs(current_step, images)
    tf.logging.info('Finished generating images')
# Out:
# WARNING:tensorflow:Estimator's model_fn (<function model_fn at 0x7f9cd613e598>) includes params argument, but params are not passed to Estimator.
# INFO:tensorflow:Using config: {'_model_dir': 'gs://tputestingmnist/DCGAN_2_in_ks3/', '_tf_random_seed': None, '_save_summary_steps': 1000, '_save_checkpoints_steps': 1000, '_save_checkpoints_secs': None, '_session_config': allow_soft_placement: true
# graph_options {
#   rewrite_options {
#     meta_optimizer_iterations: ONE
#   }
# }
# , '_keep_checkpoint_max': 3, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': None, '_train_distribute': None, '_device_fn': None, '_protocol': None, '_eval_distribute': None, '_experimental_distribute': None, '_service': None, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7f9cd60c1748>, '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': 'grpc://10.35.118.130:8470', '_evaluation_master': 'grpc://10.35.118.130:8470', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1, '_tpu_config': TPUConfig(iterations_per_loop=1000, num_shards=None, num_cores_per_replica=None, per_host_input_for_training=2, tpu_job_name=None, initial_infeed_sleep_secs=None, input_partition_dims=None), '_cluster': None}
# INFO:tensorflow:_TPUContext: eval_on_tpu True
# WARNING:tensorflow:Estimator's model_fn (<function model_fn at 0x7f9cd613e598>) includes params argument, but params are not passed to Estimator.
# INFO:tensorflow:Using config: {'_model_dir': 'gs://tputestingmnist/DCGAN_2_in_ks3/', '_tf_random_seed': None, '_save_summary_steps': 1000, '_save_checkpoints_steps': 1000, '_save_checkpoints_secs': None, '_session_config': allow_soft_placement: true
# graph_options {
#   rewrite_options {
#     meta_optimizer_iterations: ONE
#   }
# }
# , '_keep_checkpoint_max': 3, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': None, '_train_distribute': None, '_device_fn': None, '_protocol': None, '_eval_distribute': None, '_experimental_distribute': None, '_service': None, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7f9cd60c19b0>, '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': 'grpc://10.35.118.130:8470', '_evaluation_master': 'grpc://10.35.118.130:8470', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1, '_tpu_config': TPUConfig(iterations_per_loop=1000, num_shards=None, num_cores_per_replica=None, per_host_input_for_training=2, tpu_job_name=None, initial_infeed_sleep_secs=None, input_partition_dims=None), '_cluster': None}
# INFO:tensorflow:_TPUContext: eval_on_tpu True
# WARNING:tensorflow:eval_on_tpu ignored because use_tpu is False.
# INFO:tensorflow:Starting training
# INFO:tensorflow:Querying Tensorflow master (grpc://10.35.118.130:8470) for TPU system metadata.
# INFO:tensorflow:Found TPU system:
# INFO:tensorflow:*** Num TPU Cores: 8
# INFO:tensorflow:*** Num TPU Workers: 1
# INFO:tensorflow:*** Num TPU Cores Per Worker: 8
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:tpu_worker/replica:0/task:0/device:CPU:0, CPU, -1, 15292792527388281386)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:tpu_worker/replica:0/task:0/device:XLA_CPU:0, XLA_CPU, 17179869184, 14082490873688983048)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:tpu_worker/replica:0/task:0/device:TPU:0, TPU, 17179869184, 1833546660430673527)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:tpu_worker/replica:0/task:0/device:TPU:1, TPU, 17179869184, 17030284217082981092)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:tpu_worker/replica:0/task:0/device:TPU:2, TPU, 17179869184, 5950631973140130559)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:tpu_worker/replica:0/task:0/device:TPU:3, TPU, 17179869184, 7927274599759994106)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:tpu_worker/replica:0/task:0/device:TPU:4, TPU, 17179869184, 9681910699245156122)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:tpu_worker/replica:0/task:0/device:TPU:5, TPU, 17179869184, 1691348496872530242)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:tpu_worker/replica:0/task:0/device:TPU:6, TPU, 17179869184, 7007812894175061383)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:tpu_worker/replica:0/task:0/device:TPU:7, TPU, 17179869184, 18410172392670574699)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:tpu_worker/replica:0/task:0/device:TPU_SYSTEM:0, TPU_SYSTEM, 17179869184, 15613001502286366324)
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/resource_variable_ops.py:435: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:From <ipython-input-6-fa545c982a59>:21: dense (from tensorflow.python.layers.core) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.dense instead.
# WARNING:tensorflow:From <ipython-input-6-fa545c982a59>:35: conv2d_transpose (from tensorflow.python.layers.convolutional) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.conv2d_transpose instead.
# WARNING:tensorflow:From <ipython-input-6-fa545c982a59>:16: batch_normalization (from tensorflow.python.layers.normalization) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.batch_normalization instead.
# WARNING:tensorflow:From <ipython-input-6-fa545c982a59>:28: conv2d (from tensorflow.python.layers.convolutional) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.conv2d instead.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/losses/losses_impl.py:209: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:TPU job name tpu_worker
# INFO:tensorflow:Graph was finalized.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/training/saver.py:1266: checkpoint_exists (from tensorflow.python.training.checkpoint_management) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use standard file APIs to check for files with this prefix.
# INFO:tensorflow:Restoring parameters from gs://tputestingmnist/DCGAN_2_in_ks3/model.ckpt-100
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/training/saver.py:1070: get_checkpoint_mtimes (from tensorflow.python.training.checkpoint_management) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use standard file utilities to get mtimes.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 100 into gs://tputestingmnist/DCGAN_2_in_ks3/model.ckpt.
# INFO:tensorflow:Initialized dataset iterators in 0 seconds
# INFO:tensorflow:Installing graceful shutdown hook.
# INFO:tensorflow:Creating heartbeat manager for ['/job:tpu_worker/replica:0/task:0/device:CPU:0']
# INFO:tensorflow:Configuring worker heartbeat: shutdown_mode: WAIT_FOR_COORDINATOR
#
# INFO:tensorflow:Init TPU system
# INFO:tensorflow:Initialized TPU in 36 seconds
# INFO:tensorflow:Starting infeed thread controller.
# INFO:tensorflow:Starting outfeed thread controller.
# INFO:tensorflow:Enqueue next (1000) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1000) batch(es) of data from outfeed.
# INFO:tensorflow:Saving checkpoints for 1100 into gs://tputestingmnist/DCGAN_2_in_ks3/model.ckpt.
# INFO:tensorflow:loss = 2.2436507, step = 1100
# INFO:tensorflow:Stop infeed thread controller
# INFO:tensorflow:Shutting down InfeedController thread.
# INFO:tensorflow:InfeedController received shutdown signal, stopping.
# INFO:tensorflow:Infeed thread finished, shutting down.
# INFO:tensorflow:infeed marked as finished
# INFO:tensorflow:Stop output thread controller
# INFO:tensorflow:Shutting down OutfeedController thread.
# INFO:tensorflow:OutfeedController received shutdown signal, stopping.
# INFO:tensorflow:Outfeed thread finished, shutting down.
# INFO:tensorflow:outfeed marked as finished
# INFO:tensorflow:Shutdown TPU system.
# INFO:tensorflow:Loss for final step: 2.2436507.
# INFO:tensorflow:training_loop marked as finished
# INFO:tensorflow:Finished training step 1100
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/contrib/tpu/python/tpu/tpu_estimator.py:2655: div (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Deprecated in favor of operator or tf.math.divide.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-05-19T19:16:15Z
# INFO:tensorflow:TPU job name tpu_worker
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from gs://tputestingmnist/DCGAN_2_in_ks3/model.ckpt-1100
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Init TPU system
# INFO:tensorflow:Initialized TPU in 67 seconds
# INFO:tensorflow:Starting infeed thread controller.
# INFO:tensorflow:Starting outfeed thread controller.
# INFO:tensorflow:Initialized dataset iterators in 0 seconds
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Evaluation [1/1]
# INFO:tensorflow:Stop infeed thread controller
# INFO:tensorflow:Shutting down InfeedController thread.
# INFO:tensorflow:InfeedController received shutdown signal, stopping.
# INFO:tensorflow:Infeed thread finished, shutting down.
# INFO:tensorflow:infeed marked as finished
# INFO:tensorflow:Stop output thread controller
# INFO:tensorflow:Shutting down OutfeedController thread.
# INFO:tensorflow:OutfeedController received shutdown signal, stopping.
# INFO:tensorflow:Outfeed thread finished, shutting down.
# INFO:tensorflow:outfeed marked as finished
# INFO:tensorflow:Shutdown TPU system.
# INFO:tensorflow:Finished evaluation at 2019-05-19-19:17:27
# INFO:tensorflow:Saving dict for global step 1100: discriminator_gen_accuracy = 1.0, discriminator_loss = 0.5116497, discriminator_real_accuracy = 0.9863281, generator_loss = 2.147119, global_step = 1100, loss = 2.1315181
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 1100: gs://tputestingmnist/DCGAN_2_in_ks3/model.ckpt-1100
# INFO:tensorflow:evaluation_loop marked as finished
# INFO:tensorflow:Finished evaluating
# INFO:tensorflow:{'discriminator_gen_accuracy': 1.0, 'discriminator_loss': 0.5116497, 'discriminator_real_accuracy': 0.9863281, 'generator_loss': 2.147119, 'loss': 2.1315181, 'global_step': 1100}
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Running infer on CPU
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from gs://tputestingmnist/DCGAN_2_in_ks3/model.ckpt-1100
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:prediction_loop marked as finished
# INFO:tensorflow:prediction_loop marked as finished
# INFO:tensorflow:Finished generating images
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:TPU job name tpu_worker
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from gs://tputestingmnist/DCGAN_2_in_ks3/model.ckpt-1100
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 1100 into gs://tputestingmnist/DCGAN_2_in_ks3/model.ckpt.
# INFO:tensorflow:Initialized dataset iterators in 0 seconds
# INFO:tensorflow:Installing graceful shutdown hook.
# INFO:tensorflow:Creating heartbeat manager for ['/job:tpu_worker/replica:0/task:0/device:CPU:0']
# INFO:tensorflow:Configuring worker heartbeat: shutdown_mode: WAIT_FOR_COORDINATOR
#
# INFO:tensorflow:Init TPU system
# INFO:tensorflow:Initialized TPU in 84 seconds
# INFO:tensorflow:Starting infeed thread controller.
# INFO:tensorflow:Starting outfeed thread controller.
# INFO:tensorflow:Enqueue next (1000) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1000) batch(es) of data from outfeed.
# INFO:tensorflow:Saving checkpoints for 2100 into gs://tputestingmnist/DCGAN_2_in_ks3/model.ckpt.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/training/saver.py:966: remove_checkpoint (from tensorflow.python.training.checkpoint_management) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use standard file APIs to delete files with this prefix.
# INFO:tensorflow:loss = 2.147739, step = 2100
# INFO:tensorflow:Stop infeed thread controller
# INFO:tensorflow:Shutting down InfeedController thread.
# INFO:tensorflow:InfeedController received shutdown signal, stopping.
# INFO:tensorflow:Infeed thread finished, shutting down.
# INFO:tensorflow:infeed marked as finished
# INFO:tensorflow:Stop output thread controller
# INFO:tensorflow:Shutting down OutfeedController thread.
# INFO:tensorflow:OutfeedController received shutdown signal, stopping.
# INFO:tensorflow:Outfeed thread finished, shutting down.
# INFO:tensorflow:outfeed marked as finished
# INFO:tensorflow:Shutdown TPU system.
# INFO:tensorflow:Loss for final step: 2.147739.
# INFO:tensorflow:training_loop marked as finished
# INFO:tensorflow:Finished training step 2100
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-05-19T19:19:44Z
# INFO:tensorflow:TPU job name tpu_worker
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from gs://tputestingmnist/DCGAN_2_in_ks3/model.ckpt-2100
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Init TPU system
# INFO:tensorflow:Initialized TPU in 67 seconds
# INFO:tensorflow:Starting infeed thread controller.
# INFO:tensorflow:Starting outfeed thread controller.
# INFO:tensorflow:Initialized dataset iterators in 0 seconds
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Evaluation [1/1]
# INFO:tensorflow:Stop infeed thread controller
# INFO:tensorflow:Shutting down InfeedController thread.
# INFO:tensorflow:InfeedController received shutdown signal, stopping.
# INFO:tensorflow:Infeed thread finished, shutting down.
# INFO:tensorflow:infeed marked as finished
# INFO:tensorflow:Stop output thread controller
# INFO:tensorflow:Shutting down OutfeedController thread.
# INFO:tensorflow:OutfeedController received shutdown signal, stopping.
# INFO:tensorflow:Outfeed thread finished, shutting down.
# INFO:tensorflow:outfeed marked as finished
# INFO:tensorflow:Shutdown TPU system.
# INFO:tensorflow:Finished evaluation at 2019-05-19-19:20:55
# INFO:tensorflow:Saving dict for global step 2100: discriminator_gen_accuracy = 1.0, discriminator_loss = 0.47094485, discriminator_real_accuracy = 1.0, generator_loss = 2.7347403, global_step = 2100, loss = 2.6750667
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 2100: gs://tputestingmnist/DCGAN_2_in_ks3/model.ckpt-2100
# INFO:tensorflow:evaluation_loop marked as finished
# INFO:tensorflow:Finished evaluating
# INFO:tensorflow:{'discriminator_gen_accuracy': 1.0, 'discriminator_loss': 0.47094485, 'discriminator_real_accuracy': 1.0, 'generator_loss': 2.7347403, 'loss': 2.6750667, 'global_step': 2100}
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Running infer on CPU
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from gs://tputestingmnist/DCGAN_2_in_ks3/model.ckpt-2100
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:prediction_loop marked as finished
# INFO:tensorflow:prediction_loop marked as finished
# INFO:tensorflow:Finished generating images
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:TPU job name tpu_worker
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from gs://tputestingmnist/DCGAN_2_in_ks3/model.ckpt-2100
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 2100 into gs://tputestingmnist/DCGAN_2_in_ks3/model.ckpt.
# INFO:tensorflow:Initialized dataset iterators in 0 seconds
# INFO:tensorflow:Installing graceful shutdown hook.
# INFO:tensorflow:Creating heartbeat manager for ['/job:tpu_worker/replica:0/task:0/device:CPU:0']
# INFO:tensorflow:Configuring worker heartbeat: shutdown_mode: WAIT_FOR_COORDINATOR
#
# INFO:tensorflow:Init TPU system
# INFO:tensorflow:Initialized TPU in 86 seconds
# INFO:tensorflow:Starting infeed thread controller.
# INFO:tensorflow:Starting outfeed thread controller.
# INFO:tensorflow:Enqueue next (1000) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1000) batch(es) of data from outfeed.
# INFO:tensorflow:Saving checkpoints for 3100 into gs://tputestingmnist/DCGAN_2_in_ks3/model.ckpt.
# INFO:tensorflow:loss = 1.6158956, step = 3100
# INFO:tensorflow:Stop infeed thread controller
# INFO:tensorflow:Shutting down InfeedController thread.
# INFO:tensorflow:InfeedController received shutdown signal, stopping.
# INFO:tensorflow:Infeed thread finished, shutting down.
# INFO:tensorflow:infeed marked as finished
# INFO:tensorflow:Stop output thread controller
# INFO:tensorflow:Shutting down OutfeedController thread.
# INFO:tensorflow:OutfeedController received shutdown signal, stopping.
# INFO:tensorflow:Outfeed thread finished, shutting down.
# INFO:tensorflow:outfeed marked as finished
# INFO:tensorflow:Shutdown TPU system.
# INFO:tensorflow:Loss for final step: 1.6158956.
# INFO:tensorflow:training_loop marked as finished
# INFO:tensorflow:Finished training step 3100
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-05-19T19:23:13Z
# INFO:tensorflow:TPU job name tpu_worker
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from gs://tputestingmnist/DCGAN_2_in_ks3/model.ckpt-3100
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Init TPU system
# INFO:tensorflow:Initialized TPU in 65 seconds
# INFO:tensorflow:Starting infeed thread controller.
# INFO:tensorflow:Starting outfeed thread controller.
# INFO:tensorflow:Initialized dataset iterators in 0 seconds
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Evaluation [1/1]
# INFO:tensorflow:Stop infeed thread controller
# INFO:tensorflow:Shutting down InfeedController thread.
# INFO:tensorflow:InfeedController received shutdown signal, stopping.
# INFO:tensorflow:Infeed thread finished, shutting down.
# INFO:tensorflow:infeed marked as finished
# INFO:tensorflow:Stop output thread controller
# INFO:tensorflow:Shutting down OutfeedController thread.
# INFO:tensorflow:OutfeedController received shutdown signal, stopping.
# INFO:tensorflow:Outfeed thread finished, shutting down.
# INFO:tensorflow:outfeed marked as finished
# INFO:tensorflow:Shutdown TPU system.
# INFO:tensorflow:Finished evaluation at 2019-05-19-19:24:23
# INFO:tensorflow:Saving dict for global step 3100: discriminator_gen_accuracy = 1.0, discriminator_loss = 0.66972655, discriminator_real_accuracy = 0.6669922, generator_loss = 3.834329, global_step = 3100, loss = 3.4651234
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 3100: gs://tputestingmnist/DCGAN_2_in_ks3/model.ckpt-3100
# INFO:tensorflow:evaluation_loop marked as finished
# INFO:tensorflow:Finished evaluating
# INFO:tensorflow:{'discriminator_gen_accuracy': 1.0, 'discriminator_loss': 0.66972655, 'discriminator_real_accuracy': 0.6669922, 'generator_loss': 3.834329, 'loss': 3.4651234, 'global_step': 3100}
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Running infer on CPU
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from gs://tputestingmnist/DCGAN_2_in_ks3/model.ckpt-3100
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:prediction_loop marked as finished
# INFO:tensorflow:prediction_loop marked as finished
# INFO:tensorflow:Finished generating images
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:TPU job name tpu_worker
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from gs://tputestingmnist/DCGAN_2_in_ks3/model.ckpt-3100
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 3100 into gs://tputestingmnist/DCGAN_2_in_ks3/model.ckpt.
# INFO:tensorflow:Initialized dataset iterators in 0 seconds
# INFO:tensorflow:Installing graceful shutdown hook.
# INFO:tensorflow:Creating heartbeat manager for ['/job:tpu_worker/replica:0/task:0/device:CPU:0']
# INFO:tensorflow:Configuring worker heartbeat: shutdown_mode: WAIT_FOR_COORDINATOR
#
# INFO:tensorflow:Init TPU system
# INFO:tensorflow:Initialized TPU in 87 seconds
# INFO:tensorflow:Starting infeed thread controller.
# INFO:tensorflow:Starting outfeed thread controller.
# INFO:tensorflow:Enqueue next (1000) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1000) batch(es) of data from outfeed.
# INFO:tensorflow:Saving checkpoints for 4100 into gs://tputestingmnist/DCGAN_2_in_ks3/model.ckpt.
# INFO:tensorflow:loss = 2.1587818, step = 4100
# INFO:tensorflow:Stop infeed thread controller
# INFO:tensorflow:Shutting down InfeedController thread.
# INFO:tensorflow:InfeedController received shutdown signal, stopping.
# INFO:tensorflow:Infeed thread finished, shutting down.
# INFO:tensorflow:infeed marked as finished
# INFO:tensorflow:Stop output thread controller
# INFO:tensorflow:Shutting down OutfeedController thread.
# INFO:tensorflow:OutfeedController received shutdown signal, stopping.
# INFO:tensorflow:Outfeed thread finished, shutting down.
# INFO:tensorflow:outfeed marked as finished
# INFO:tensorflow:Shutdown TPU system.
# INFO:tensorflow:Loss for final step: 2.1587818.
# INFO:tensorflow:training_loop marked as finished
# INFO:tensorflow:Finished training step 4100
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-05-19T19:26:40Z
# INFO:tensorflow:TPU job name tpu_worker
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from gs://tputestingmnist/DCGAN_2_in_ks3/model.ckpt-4100
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Init TPU system
# INFO:tensorflow:Initialized TPU in 66 seconds
# INFO:tensorflow:Starting infeed thread controller.
# INFO:tensorflow:Starting outfeed thread controller.
# INFO:tensorflow:Initialized dataset iterators in 0 seconds
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Evaluation [1/1]
# INFO:tensorflow:Stop infeed thread controller
# INFO:tensorflow:Shutting down InfeedController thread.
# INFO:tensorflow:InfeedController received shutdown signal, stopping.
# INFO:tensorflow:Infeed thread finished, shutting down.
# INFO:tensorflow:infeed marked as finished
# INFO:tensorflow:Stop output thread controller
# INFO:tensorflow:Shutting down OutfeedController thread.
# INFO:tensorflow:OutfeedController received shutdown signal, stopping.
# INFO:tensorflow:Outfeed thread finished, shutting down.
# INFO:tensorflow:outfeed marked as finished
# INFO:tensorflow:Shutdown TPU system.
# INFO:tensorflow:Finished evaluation at 2019-05-19-19:27:51
# INFO:tensorflow:Saving dict for global step 4100: discriminator_gen_accuracy = 1.0, discriminator_loss = 0.47062135, discriminator_real_accuracy = 1.0, generator_loss = 2.3039734, global_step = 4100, loss = 2.243644
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 4100: gs://tputestingmnist/DCGAN_2_in_ks3/model.ckpt-4100
# INFO:tensorflow:evaluation_loop marked as finished
# INFO:tensorflow:Finished evaluating
# INFO:tensorflow:{'discriminator_gen_accuracy': 1.0, 'discriminator_loss': 0.47062135, 'discriminator_real_accuracy': 1.0, 'generator_loss': 2.3039734, 'loss': 2.243644, 'global_step': 4100}
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Running infer on CPU
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from gs://tputestingmnist/DCGAN_2_in_ks3/model.ckpt-4100
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:prediction_loop marked as finished
# INFO:tensorflow:prediction_loop marked as finished
# INFO:tensorflow:Finished generating images
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:TPU job name tpu_worker
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from gs://tputestingmnist/DCGAN_2_in_ks3/model.ckpt-4100
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 4100 into gs://tputestingmnist/DCGAN_2_in_ks3/model.ckpt.
# INFO:tensorflow:Initialized dataset iterators in 0 seconds
# INFO:tensorflow:Installing graceful shutdown hook.
# INFO:tensorflow:Creating heartbeat manager for ['/job:tpu_worker/replica:0/task:0/device:CPU:0']
# INFO:tensorflow:Configuring worker heartbeat: shutdown_mode: WAIT_FOR_COORDINATOR
#
# INFO:tensorflow:Init TPU system
# INFO:tensorflow:Initialized TPU in 86 seconds
# INFO:tensorflow:Starting infeed thread controller.
# INFO:tensorflow:Starting outfeed thread controller.
# INFO:tensorflow:Enqueue next (1000) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1000) batch(es) of data from outfeed.
# INFO:tensorflow:Saving checkpoints for 5100 into gs://tputestingmnist/DCGAN_2_in_ks3/model.ckpt.
# INFO:tensorflow:loss = 2.7062998, step = 5100
# INFO:tensorflow:Stop infeed thread controller
# INFO:tensorflow:Shutting down InfeedController thread.
# INFO:tensorflow:InfeedController received shutdown signal, stopping.
# INFO:tensorflow:Infeed thread finished, shutting down.
# INFO:tensorflow:infeed marked as finished
# INFO:tensorflow:Stop output thread controller
# INFO:tensorflow:Shutting down OutfeedController thread.
# INFO:tensorflow:OutfeedController received shutdown signal, stopping.
# INFO:tensorflow:Outfeed thread finished, shutting down.
# INFO:tensorflow:outfeed marked as finished
# INFO:tensorflow:Shutdown TPU system.
# INFO:tensorflow:Loss for final step: 2.7062998.
# INFO:tensorflow:training_loop marked as finished
# INFO:tensorflow:Finished training step 5100
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-05-19T19:30:09Z
# INFO:tensorflow:TPU job name tpu_worker
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from gs://tputestingmnist/DCGAN_2_in_ks3/model.ckpt-5100
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Init TPU system
# INFO:tensorflow:Initialized TPU in 65 seconds
# INFO:tensorflow:Starting infeed thread controller.
# INFO:tensorflow:Starting outfeed thread controller.
# INFO:tensorflow:Initialized dataset iterators in 0 seconds
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Evaluation [1/1]
# INFO:tensorflow:Stop infeed thread controller
# INFO:tensorflow:Shutting down InfeedController thread.
# INFO:tensorflow:InfeedController received shutdown signal, stopping.
# INFO:tensorflow:Infeed thread finished, shutting down.
# INFO:tensorflow:infeed marked as finished
# INFO:tensorflow:Stop output thread controller
# INFO:tensorflow:Shutting down OutfeedController thread.
# INFO:tensorflow:OutfeedController received shutdown signal, stopping.
# INFO:tensorflow:Outfeed thread finished, shutting down.
# INFO:tensorflow:outfeed marked as finished
# INFO:tensorflow:Shutdown TPU system.
# INFO:tensorflow:Finished evaluation at 2019-05-19-19:31:19
# INFO:tensorflow:Saving dict for global step 5100: discriminator_gen_accuracy = 1.0, discriminator_loss = 0.5372188, discriminator_real_accuracy = 1.0, generator_loss = 1.7707646, global_step = 5100, loss = 1.8704199
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 5100: gs://tputestingmnist/DCGAN_2_in_ks3/model.ckpt-5100
# INFO:tensorflow:evaluation_loop marked as finished
# INFO:tensorflow:Finished evaluating
# INFO:tensorflow:{'discriminator_gen_accuracy': 1.0, 'discriminator_loss': 0.5372188, 'discriminator_real_accuracy': 1.0, 'generator_loss': 1.7707646, 'loss': 1.8704199, 'global_step': 5100}
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Running infer on CPU
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from gs://tputestingmnist/DCGAN_2_in_ks3/model.ckpt-5100
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:prediction_loop marked as finished
# INFO:tensorflow:prediction_loop marked as finished
# INFO:tensorflow:Finished generating images
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:TPU job name tpu_worker
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from gs://tputestingmnist/DCGAN_2_in_ks3/model.ckpt-5100
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 5100 into gs://tputestingmnist/DCGAN_2_in_ks3/model.ckpt.
# INFO:tensorflow:Initialized dataset iterators in 0 seconds
# INFO:tensorflow:Installing graceful shutdown hook.
# INFO:tensorflow:Creating heartbeat manager for ['/job:tpu_worker/replica:0/task:0/device:CPU:0']
# INFO:tensorflow:Configuring worker heartbeat: shutdown_mode: WAIT_FOR_COORDINATOR
#
# INFO:tensorflow:Init TPU system
# INFO:tensorflow:Initialized TPU in 86 seconds
# INFO:tensorflow:Starting infeed thread controller.
# INFO:tensorflow:Starting outfeed thread controller.
# INFO:tensorflow:Enqueue next (1000) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1000) batch(es) of data from outfeed.
# INFO:tensorflow:Saving checkpoints for 6100 into gs://tputestingmnist/DCGAN_2_in_ks3/model.ckpt.
# INFO:tensorflow:loss = 4.774019, step = 6100
# INFO:tensorflow:Stop infeed thread controller
# INFO:tensorflow:Shutting down InfeedController thread.
# INFO:tensorflow:InfeedController received shutdown signal, stopping.
# INFO:tensorflow:Infeed thread finished, shutting down.
# INFO:tensorflow:infeed marked as finished
# INFO:tensorflow:Stop output thread controller
# INFO:tensorflow:Shutting down OutfeedController thread.
# INFO:tensorflow:OutfeedController received shutdown signal, stopping.
# INFO:tensorflow:Outfeed thread finished, shutting down.
# INFO:tensorflow:outfeed marked as finished
# INFO:tensorflow:Shutdown TPU system.
# INFO:tensorflow:Loss for final step: 4.774019.
# INFO:tensorflow:training_loop marked as finished
# INFO:tensorflow:Finished training step 6100
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-05-19T19:33:36Z
# INFO:tensorflow:TPU job name tpu_worker
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from gs://tputestingmnist/DCGAN_2_in_ks3/model.ckpt-6100
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Init TPU system
# INFO:tensorflow:Initialized TPU in 66 seconds
# INFO:tensorflow:Starting infeed thread controller.
# INFO:tensorflow:Starting outfeed thread controller.
# INFO:tensorflow:Initialized dataset iterators in 0 seconds
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Evaluation [1/1]
# INFO:tensorflow:Stop infeed thread controller
# INFO:tensorflow:Shutting down InfeedController thread.
# INFO:tensorflow:InfeedController received shutdown signal, stopping.
# INFO:tensorflow:Infeed thread finished, shutting down.
# INFO:tensorflow:infeed marked as finished
# INFO:tensorflow:Stop output thread controller
# INFO:tensorflow:Shutting down OutfeedController thread.
# INFO:tensorflow:OutfeedController received shutdown signal, stopping.
# INFO:tensorflow:Outfeed thread finished, shutting down.
# INFO:tensorflow:outfeed marked as finished
# INFO:tensorflow:Shutdown TPU system.
# INFO:tensorflow:Finished evaluation at 2019-05-19-19:34:47
# INFO:tensorflow:Saving dict for global step 6100: discriminator_gen_accuracy = 1.0, discriminator_loss = 0.45251912, discriminator_real_accuracy = 1.0, generator_loss = 2.6301336, global_step = 6100, loss = 2.8552172
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 6100: gs://tputestingmnist/DCGAN_2_in_ks3/model.ckpt-6100
# INFO:tensorflow:evaluation_loop marked as finished
# INFO:tensorflow:Finished evaluating
# INFO:tensorflow:{'discriminator_gen_accuracy': 1.0, 'discriminator_loss': 0.45251912, 'discriminator_real_accuracy': 1.0, 'generator_loss': 2.6301336, 'loss': 2.8552172, 'global_step': 6100}
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Running infer on CPU
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from gs://tputestingmnist/DCGAN_2_in_ks3/model.ckpt-6100
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:prediction_loop marked as finished
# INFO:tensorflow:prediction_loop marked as finished
# INFO:tensorflow:Finished generating images
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:TPU job name tpu_worker
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from gs://tputestingmnist/DCGAN_2_in_ks3/model.ckpt-6100
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 6100 into gs://tputestingmnist/DCGAN_2_in_ks3/model.ckpt.
# INFO:tensorflow:Initialized dataset iterators in 0 seconds
# INFO:tensorflow:Installing graceful shutdown hook.
# INFO:tensorflow:Creating heartbeat manager for ['/job:tpu_worker/replica:0/task:0/device:CPU:0']
# INFO:tensorflow:Configuring worker heartbeat: shutdown_mode: WAIT_FOR_COORDINATOR
#
# INFO:tensorflow:Init TPU system
# INFO:tensorflow:Initialized TPU in 86 seconds
# INFO:tensorflow:Starting infeed thread controller.
# INFO:tensorflow:Starting outfeed thread controller.
# INFO:tensorflow:Enqueue next (1000) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1000) batch(es) of data from outfeed.
# INFO:tensorflow:Saving checkpoints for 7100 into gs://tputestingmnist/DCGAN_2_in_ks3/model.ckpt.
# INFO:tensorflow:loss = 3.612096, step = 7100
# INFO:tensorflow:Stop infeed thread controller
# INFO:tensorflow:Shutting down InfeedController thread.
# INFO:tensorflow:InfeedController received shutdown signal, stopping.
# INFO:tensorflow:Infeed thread finished, shutting down.
# INFO:tensorflow:infeed marked as finished
# INFO:tensorflow:Stop output thread controller
# INFO:tensorflow:Shutting down OutfeedController thread.
# INFO:tensorflow:OutfeedController received shutdown signal, stopping.
# INFO:tensorflow:Outfeed thread finished, shutting down.
# INFO:tensorflow:outfeed marked as finished
# INFO:tensorflow:Shutdown TPU system.
# INFO:tensorflow:Loss for final step: 3.612096.
# INFO:tensorflow:training_loop marked as finished
# INFO:tensorflow:Finished training step 7100
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-05-19T19:37:04Z
# INFO:tensorflow:TPU job name tpu_worker
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from gs://tputestingmnist/DCGAN_2_in_ks3/model.ckpt-7100
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Init TPU system
# INFO:tensorflow:Initialized TPU in 66 seconds
# INFO:tensorflow:Starting infeed thread controller.
# INFO:tensorflow:Initialized dataset iterators in 0 seconds
# INFO:tensorflow:Starting outfeed thread controller.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Evaluation [1/1]
# INFO:tensorflow:Stop infeed thread controller
# INFO:tensorflow:Shutting down InfeedController thread.
# INFO:tensorflow:InfeedController received shutdown signal, stopping.
# INFO:tensorflow:Infeed thread finished, shutting down.
# INFO:tensorflow:infeed marked as finished
# INFO:tensorflow:Stop output thread controller
# INFO:tensorflow:Shutting down OutfeedController thread.
# INFO:tensorflow:OutfeedController received shutdown signal, stopping.
# INFO:tensorflow:Outfeed thread finished, shutting down.
# INFO:tensorflow:outfeed marked as finished
# INFO:tensorflow:Shutdown TPU system.
# INFO:tensorflow:Finished evaluation at 2019-05-19-19:38:15
# INFO:tensorflow:Saving dict for global step 7100: discriminator_gen_accuracy = 1.0, discriminator_loss = 0.36126706, discriminator_real_accuracy = 1.0, generator_loss = 3.6395445, global_step = 7100, loss = 3.6140218
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 7100: gs://tputestingmnist/DCGAN_2_in_ks3/model.ckpt-7100
# INFO:tensorflow:evaluation_loop marked as finished
# INFO:tensorflow:Finished evaluating
# INFO:tensorflow:{'discriminator_gen_accuracy': 1.0, 'discriminator_loss': 0.36126706, 'discriminator_real_accuracy': 1.0, 'generator_loss': 3.6395445, 'loss': 3.6140218, 'global_step': 7100}
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Running infer on CPU
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from gs://tputestingmnist/DCGAN_2_in_ks3/model.ckpt-7100
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:prediction_loop marked as finished
# INFO:tensorflow:prediction_loop marked as finished
# INFO:tensorflow:Finished generating images
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:TPU job name tpu_worker
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from gs://tputestingmnist/DCGAN_2_in_ks3/model.ckpt-7100
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 7100 into gs://tputestingmnist/DCGAN_2_in_ks3/model.ckpt.
# INFO:tensorflow:Initialized dataset iterators in 0 seconds
# INFO:tensorflow:Installing graceful shutdown hook.
# INFO:tensorflow:Creating heartbeat manager for ['/job:tpu_worker/replica:0/task:0/device:CPU:0']
# INFO:tensorflow:Configuring worker heartbeat: shutdown_mode: WAIT_FOR_COORDINATOR
#
# INFO:tensorflow:Init TPU system
# INFO:tensorflow:Initialized TPU in 86 seconds
# INFO:tensorflow:Starting infeed thread controller.
# INFO:tensorflow:Starting outfeed thread controller.
# INFO:tensorflow:Enqueue next (1000) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1000) batch(es) of data from outfeed.
# INFO:tensorflow:Saving checkpoints for 8100 into gs://tputestingmnist/DCGAN_2_in_ks3/model.ckpt.
# INFO:tensorflow:loss = 3.9314945, step = 8100
# INFO:tensorflow:Stop infeed thread controller
# INFO:tensorflow:Shutting down InfeedController thread.
# INFO:tensorflow:InfeedController received shutdown signal, stopping.
# INFO:tensorflow:Infeed thread finished, shutting down.
# INFO:tensorflow:infeed marked as finished
# INFO:tensorflow:Stop output thread controller
# INFO:tensorflow:Shutting down OutfeedController thread.
# INFO:tensorflow:OutfeedController received shutdown signal, stopping.
# INFO:tensorflow:Outfeed thread finished, shutting down.
# INFO:tensorflow:outfeed marked as finished
# INFO:tensorflow:Shutdown TPU system.
# INFO:tensorflow:Loss for final step: 3.9314945.
# INFO:tensorflow:training_loop marked as finished
# INFO:tensorflow:Finished training step 8100
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-05-19T19:40:34Z
# INFO:tensorflow:TPU job name tpu_worker
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from gs://tputestingmnist/DCGAN_2_in_ks3/model.ckpt-8100
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Init TPU system
# INFO:tensorflow:Initialized TPU in 64 seconds
# INFO:tensorflow:Starting infeed thread controller.
# INFO:tensorflow:Starting outfeed thread controller.
# INFO:tensorflow:Initialized dataset iterators in 0 seconds
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Evaluation [1/1]
# INFO:tensorflow:Stop infeed thread controller
# INFO:tensorflow:Shutting down InfeedController thread.
# INFO:tensorflow:InfeedController received shutdown signal, stopping.
# INFO:tensorflow:Infeed thread finished, shutting down.
# INFO:tensorflow:infeed marked as finished
# INFO:tensorflow:Stop output thread controller
# INFO:tensorflow:Shutting down OutfeedController thread.
# INFO:tensorflow:OutfeedController received shutdown signal, stopping.
# INFO:tensorflow:Outfeed thread finished, shutting down.
# INFO:tensorflow:outfeed marked as finished
# INFO:tensorflow:Shutdown TPU system.
# INFO:tensorflow:Finished evaluation at 2019-05-19-19:41:43
# INFO:tensorflow:Saving dict for global step 8100: discriminator_gen_accuracy = 1.0, discriminator_loss = 0.52940094, discriminator_real_accuracy = 1.0, generator_loss = 2.0841982, global_step = 8100, loss = 1.4820194
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 8100: gs://tputestingmnist/DCGAN_2_in_ks3/model.ckpt-8100
# INFO:tensorflow:evaluation_loop marked as finished
# INFO:tensorflow:Finished evaluating
# INFO:tensorflow:{'discriminator_gen_accuracy': 1.0, 'discriminator_loss': 0.52940094, 'discriminator_real_accuracy': 1.0, 'generator_loss': 2.0841982, 'loss': 1.4820194, 'global_step': 8100}
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Running infer on CPU
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from gs://tputestingmnist/DCGAN_2_in_ks3/model.ckpt-8100
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:prediction_loop marked as finished
# INFO:tensorflow:prediction_loop marked as finished
# INFO:tensorflow:Finished generating images
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:TPU job name tpu_worker
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from gs://tputestingmnist/DCGAN_2_in_ks3/model.ckpt-8100
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 8100 into gs://tputestingmnist/DCGAN_2_in_ks3/model.ckpt.
# INFO:tensorflow:Initialized dataset iterators in 0 seconds
# INFO:tensorflow:Installing graceful shutdown hook.
# INFO:tensorflow:Creating heartbeat manager for ['/job:tpu_worker/replica:0/task:0/device:CPU:0']
# INFO:tensorflow:Configuring worker heartbeat: shutdown_mode: WAIT_FOR_COORDINATOR
#
# INFO:tensorflow:Init TPU system
# INFO:tensorflow:Initialized TPU in 86 seconds
# INFO:tensorflow:Starting infeed thread controller.
# INFO:tensorflow:Starting outfeed thread controller.
# INFO:tensorflow:Enqueue next (1000) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1000) batch(es) of data from outfeed.
# INFO:tensorflow:Saving checkpoints for 9100 into gs://tputestingmnist/DCGAN_2_in_ks3/model.ckpt.
# INFO:tensorflow:loss = 3.5076516, step = 9100
# INFO:tensorflow:Stop infeed thread controller
# INFO:tensorflow:Shutting down InfeedController thread.
# INFO:tensorflow:InfeedController received shutdown signal, stopping.
# INFO:tensorflow:Infeed thread finished, shutting down.
# INFO:tensorflow:infeed marked as finished
# INFO:tensorflow:Stop output thread controller
# INFO:tensorflow:Shutting down OutfeedController thread.
# INFO:tensorflow:OutfeedController received shutdown signal, stopping.
# INFO:tensorflow:Outfeed thread finished, shutting down.
# INFO:tensorflow:outfeed marked as finished
# INFO:tensorflow:Shutdown TPU system.
# INFO:tensorflow:Loss for final step: 3.5076516.
# INFO:tensorflow:training_loop marked as finished
# INFO:tensorflow:Finished training step 9100
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-05-19T19:44:00Z
# INFO:tensorflow:TPU job name tpu_worker
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from gs://tputestingmnist/DCGAN_2_in_ks3/model.ckpt-9100
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Init TPU system
# INFO:tensorflow:Initialized TPU in 67 seconds
# INFO:tensorflow:Starting infeed thread controller.
# INFO:tensorflow:Initialized dataset iterators in 0 seconds
# INFO:tensorflow:Starting outfeed thread controller.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Evaluation [1/1]
# INFO:tensorflow:Stop infeed thread controller
# INFO:tensorflow:Shutting down InfeedController thread.
# INFO:tensorflow:InfeedController received shutdown signal, stopping.
# INFO:tensorflow:Infeed thread finished, shutting down.
# INFO:tensorflow:infeed marked as finished
# INFO:tensorflow:Stop output thread controller
# INFO:tensorflow:Shutting down OutfeedController thread.
# INFO:tensorflow:OutfeedController received shutdown signal, stopping.
# INFO:tensorflow:Outfeed thread finished, shutting down.
# INFO:tensorflow:outfeed marked as finished
# INFO:tensorflow:Shutdown TPU system.
# INFO:tensorflow:Finished evaluation at 2019-05-19-19:45:11
# INFO:tensorflow:Saving dict for global step 9100: discriminator_gen_accuracy = 1.0, discriminator_loss = 0.37265772, discriminator_real_accuracy = 1.0, generator_loss = 3.5083683, global_step = 9100, loss = 3.8820171
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 9100: gs://tputestingmnist/DCGAN_2_in_ks3/model.ckpt-9100
# INFO:tensorflow:evaluation_loop marked as finished
# INFO:tensorflow:Finished evaluating
# INFO:tensorflow:{'discriminator_gen_accuracy': 1.0, 'discriminator_loss': 0.37265772, 'discriminator_real_accuracy': 1.0, 'generator_loss': 3.5083683, 'loss': 3.8820171, 'global_step': 9100}
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Running infer on CPU
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from gs://tputestingmnist/DCGAN_2_in_ks3/model.ckpt-9100
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:prediction_loop marked as finished
# INFO:tensorflow:prediction_loop marked as finished
# INFO:tensorflow:Finished generating images
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:TPU job name tpu_worker
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from gs://tputestingmnist/DCGAN_2_in_ks3/model.ckpt-9100
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 9100 into gs://tputestingmnist/DCGAN_2_in_ks3/model.ckpt.
# INFO:tensorflow:Initialized dataset iterators in 0 seconds
# INFO:tensorflow:Installing graceful shutdown hook.
# INFO:tensorflow:Creating heartbeat manager for ['/job:tpu_worker/replica:0/task:0/device:CPU:0']
# INFO:tensorflow:Configuring worker heartbeat: shutdown_mode: WAIT_FOR_COORDINATOR
#
# INFO:tensorflow:Init TPU system
# INFO:tensorflow:Initialized TPU in 86 seconds
# INFO:tensorflow:Starting infeed thread controller.
# INFO:tensorflow:Starting outfeed thread controller.
# INFO:tensorflow:Enqueue next (900) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (900) batch(es) of data from outfeed.
# INFO:tensorflow:loss = 5.035546, step = 10000
# INFO:tensorflow:Saving checkpoints for 10000 into gs://tputestingmnist/DCGAN_2_in_ks3/model.ckpt.
# INFO:tensorflow:Stop infeed thread controller
# INFO:tensorflow:Shutting down InfeedController thread.
# INFO:tensorflow:InfeedController received shutdown signal, stopping.
# INFO:tensorflow:Infeed thread finished, shutting down.
# INFO:tensorflow:infeed marked as finished
# INFO:tensorflow:Stop output thread controller
# INFO:tensorflow:Shutting down OutfeedController thread.
# INFO:tensorflow:OutfeedController received shutdown signal, stopping.
# INFO:tensorflow:Outfeed thread finished, shutting down.
# INFO:tensorflow:outfeed marked as finished
# INFO:tensorflow:Shutdown TPU system.
# INFO:tensorflow:Loss for final step: 5.035546.
# INFO:tensorflow:training_loop marked as finished
# INFO:tensorflow:Finished training step 10000
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-05-19T19:47:26Z
# INFO:tensorflow:TPU job name tpu_worker
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from gs://tputestingmnist/DCGAN_2_in_ks3/model.ckpt-10000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Init TPU system
# INFO:tensorflow:Initialized TPU in 68 seconds
# INFO:tensorflow:Starting infeed thread controller.
# INFO:tensorflow:Starting outfeed thread controller.
# INFO:tensorflow:Initialized dataset iterators in 0 seconds
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Evaluation [1/1]
# INFO:tensorflow:Stop infeed thread controller
# INFO:tensorflow:Shutting down InfeedController thread.
# INFO:tensorflow:InfeedController received shutdown signal, stopping.
# INFO:tensorflow:Infeed thread finished, shutting down.
# INFO:tensorflow:infeed marked as finished
# INFO:tensorflow:Stop output thread controller
# INFO:tensorflow:Shutting down OutfeedController thread.
# INFO:tensorflow:OutfeedController received shutdown signal, stopping.
# INFO:tensorflow:Outfeed thread finished, shutting down.
# INFO:tensorflow:outfeed marked as finished
# INFO:tensorflow:Shutdown TPU system.
# INFO:tensorflow:Finished evaluation at 2019-05-19-19:48:39
# INFO:tensorflow:Saving dict for global step 10000: discriminator_gen_accuracy = 1.0, discriminator_loss = 0.35405868, discriminator_real_accuracy = 1.0, generator_loss = 4.0780473, global_step = 10000, loss = 3.9856002
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 10000: gs://tputestingmnist/DCGAN_2_in_ks3/model.ckpt-10000
# INFO:tensorflow:evaluation_loop marked as finished
# INFO:tensorflow:Finished evaluating
# INFO:tensorflow:{'discriminator_gen_accuracy': 1.0, 'discriminator_loss': 0.35405868, 'discriminator_real_accuracy': 1.0, 'generator_loss': 4.0780473, 'loss': 3.9856002, 'global_step': 10000}
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Running infer on CPU
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from gs://tputestingmnist/DCGAN_2_in_ks3/model.ckpt-10000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:prediction_loop marked as finished
# INFO:tensorflow:prediction_loop marked as finished
# INFO:tensorflow:Finished generating images
